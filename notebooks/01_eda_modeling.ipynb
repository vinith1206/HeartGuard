# %% [markdown]
# # EDA & Modeling Plan (UCI Heart Disease)
#
# This notebook outlines a quick EDA and baseline modeling process.
#
# ## Steps
# - Load dataset from `data/heart.csv`
# - Preview a few rows and schema
# - Check missing values
# - Plot simple histograms for key features (age, chol, trestbps, thalach)
# - Train a baseline model and evaluate
#
# ```python
# import pandas as pd
# pd.read_csv('data/heart.csv').head()
# ```
